# %%
import cv2
import numpy as np 

import tensorflow as tf
import matplotlib.pyplot as plt 
import tensorflow.contrib.keras as keras 
from tensorflow.contrib.keras import applications,layers,activations,models,losses,optimizers

from PIL import Image , ImageDraw
from PIL import Image,ImageDraw,ImageFilter
# %run find_pic.py

# %%
original_file_1 = "../images-original/war-5-5.png"
original_file_2 = "../images-original/war-6-6.png"

goal_file_1 = "../images-goal/point-c.png"
goal_file_2 = "../images-goal/point-c-2.png"

# %%
o1 = Image.open(original_file_1)
o2 = Image.open(original_file_2)
g1 = Image.open(goal_file_1)
g2 = Image.open(goal_file_2)

# %%
o1.resize(scale_16_9(255))
# Out:
# <PIL.Image.Image image mode=RGB size=453x255 at 0x27CC97D6FD0>

# %%
Image.fromarray(cv2.Canny(to_arr(g1), 30, 60))
g1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=35x35 at 0x27CC97D6390>

# %%
Image.fromarray(cv2.Canny(to_arr(g2), 30, 60))
g2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=29x30 at 0x27CC979C978>

# %%
find_by_cvMatchTemplate(
    to_arr(g1),
    to_arr(g2)
)
# Out:
# (0.60918802, 2, 2)

# %%
find_by_cvMatchTemplate(
    (cv2.Canny(to_arr(g1), 10, 100)),
    (cv2.Canny(to_arr(g2), 10, 100))
)
# Out:
# (0.2441452, 2, 2)

# %%
find_by_cvMatchTemplate(
    (cv2.Canny(to_arr(o1), 30, 60)),
    (cv2.Canny(to_arr(g1), 30, 60))
)
# Out:
# (0.94263321, 396, 443)

# %%
find_by_cvMatchTemplate(
    (cv2.Canny(to_arr(o1), 30, 60)),
    (cv2.Canny(to_arr(g2), 30, 60))
)
# Out:
# (0.22859071, 398, 445)
